# %%
import pandas as pd

# %%
field = pd.read_csv("data/original data/RecastingFieldExperiment.txt",
                         header=0, 
                         index_col=0, 
                         sep="\t")

# %%
field
# Out:
#           Plot_ID  Replicate Web_ID   MajorGroup PhylogeneticGroup  \
# Record_ID
# 1               A          1     A1    Mesofauna           Acarina
# 2               A          1     A1    Mesofauna           Acarina
# 3               A          2     A2    Mesofauna           Acarina
# 4               A          2     A2    Mesofauna           Acarina
# 5               A          2     A2    Mesofauna           Acarina
# ...           ...        ...    ...          ...               ...
# 584             B          2     B2  Plant roots           Plantae
# 585             B          3     B3  Plant roots           Plantae
# 586             C          1     C1  Plant roots           Plantae
# 587             C          2     C2  Plant roots           Plantae
# 588             C          3     C3  Plant roots           Plantae
#
#                               OTU                                   Guild  \
# Record_ID
# ...

# %%
field.to_csv("RecastingFieldExperiment.csv", index_label="Record_ID")

# %%
sfw_matrix = pd.read_csv("data/original data/sfw_matrix.csv",
                         header=0, 
                         index_col=0, 
                         sep=";")

# %%
sfw_matrix
# Out:
#                                                     11 Plant-feeding nematode  \
# CONSUMERS
# 11 Plant-feeding nematode                                                   0
# 31 Bacterivore nematode                                                     0
# 45 Substrate-ingesting earthworm                                            0
# 23 Fungivore insect                                                         0
# 24 Fungivore enchytraeid                                                    0
# 21 Fungivore nematode                                                       0
# 81 Omnivore nematode                                                        0
# 13 Plant-feeding insect (springtail)                                        0
# 44 Substrate-inhabiting enchytraeid                                         0
# 51 Predating nematode (consuming nematodes)                                 0
# 72 Generalist mite                                                          0
# ...

# %%
sfw_matrix.to_csv("sfw_matrix.csv")

# %%
sfw_trophic_levels = pd.read_csv("data/original data/sfw_trophic_levels.csv", sep=";", header=None)

# %%
sfw_trophic_levels
# Out:
#                                                     0  1
# 0                           11 Plant-feeding nematode  1
# 1                             31 Bacterivore nematode  1
# 2                    45 Substrate-ingesting earthworm  1
# 3                                 23 Fungivore insect  1
# 4                            24 Fungivore enchytraeid  1
# 5                               21 Fungivore nematode  1
# 6                                81 Omnivore nematode  2
# 7                13 Plant-feeding insect (springtail)  1
# 8                 44 Substrate-inhabiting enchytraeid  1
# 9         51 Predating nematode (consuming nematodes)  3
# 10                                 72 Generalist mite  3
# 11                         34 Bacterivore enchytraeid  1
# 12                                   82 Omnivore mite  2
# 13          12 Macrophytophage and panphytophage mite  1
# 14                             36 Bacterivore amoebae  1
# ...

# %%
sfw_trophic_levels.to_csv("sfw_trophic_levels.csv", index=None, header=None)
